# %%
 #DICTIONARIES

d = {"name": "John", "age": 20}

print(d["name"])     # Access using key
print(d.get("age"))  # Access using get()

d = {"name": "Sam"}

d["age"] = 21        # Adding a new key-value pair
d["name"] = "Alex"   # Updating an existing value
print(d)

del d["age"]
print(d) # Deleting Items
# Out:
# John
# 20
# {'name': 'Alex', 'age': 21}
# {'name': 'Alex'}

# %%
d = {"name": "John", "age": 20}

val = d.pop("name") # Using pop()
print(val)
print(d)

d = {"name": "John", "age": 20} # Using popitem()
print(d.popitem())

print(d.clear()) # clear() empties the dictionary
# Out:
# John
# {'age': 20}
# ('age', 20)
# None

# %%
d = {"a": 1, "b": 2, "c": 3, "d": 4}
for key, value in d.items():
    print(key, value) # Iterating through values
# Out:
# a 1
# b 2
# c 3
# d 4

# %%
d = {
    "code": {
        "tool": "Colab",
        "time": 20
    }
}

print(d["code"]["tool"])
# Out:
# Colab
